# %%
import sys
from pathlib import Path

project_root = Path.cwd().parents[2]
print(project_root)
sys.path.append(str(project_root))

summary_list = {
    "interests_categories": [
        "생성형 AI와 멀티모달 AI 기술이 AI 헬스케어 및 디지털 치료제 산업에 혁신을 가져올 것으로 보며, 실생활에서는 온디바이스 AI가 탑재된 스마트 기기의 투자 매력도를 높게 평가하는 기술 혁신 지향적인 투자자입니다.",
        "수소 에너지와 차세대 태양광 기술의 미래 성장성을 믿으며, 전기차 및 관련 인프라 산업에서 사회·경제적 변화의 기회를 찾고, 실생활에서는 스마트 그리드와 가정용 에너지 관리 시스템에 높은 투자 매력을 느끼는 친환경 에너지 전환 지지자입니다.",
        "유전자 편집 기술과 합성 생물학에 큰 관심을 가지고 있으며, 고령화 사회에 따른 실버 및 재생 의료 산업에서 기회를 보고, 실생활에서는 개인 맞춤형 영양제 시장의 투자 매력도를 높게 평가하는 바이오테크 중심의 투자자입니다.",
        "완전 자율주행과 도심 항공 모빌리티(UAM) 기술의 잠재력을 높이 평가하고, 스마트 물류 및 배송 로봇 산업에서 큰 기회를 보며, 실생활에서는 구독 기반의 모빌리티 서비스(MaaS)에 투자 매력을 느끼는 미래 모빌리티 지향적 투자자입니다.",
        "클라우드 및 엣지 컴퓨팅 기술을 미래 성장 동력으로 보고, 지능형 자율제조와 스마트 팩토리 산업에서 사회 변화의 기회를 찾으며, 실생활에서는 SaaS 기반의 원격 근무 툴의 투자 매력도를 높게 평가하는 디지털 전환 전문가입니다.",
        "확장현실(XR)과 디지털 트윈 기술에 주목하며, 디지털 휴먼 및 가상 인플루언서 산업에서 새로운 기회를 발견하고, 실생활에서는 VR 기반 소셜 플랫폼 및 게임 콘텐츠에 높은 투자 매력을 느끼는 메타버스 지향적 투자자입니다.",
        "다기능 휴머노이드 로봇 기술을 미래 성장 동력으로 생각하고, 스마트 농업 및 농업 자동화 산업에서 사회적 변화의 기회를 찾으며, 실생활에서는 다양한 서비스 로봇 분야의 투자 매력도를 높게 평가하는 로보틱스 기술 신봉자입니다.",
        "AI 반도체와 차세대 전력 반도체를 핵심 성장 기술로 보고, 데이터 센터 및 클라우드 서비스 산업에서 큰 기회를 포착하며, 실생활에서는 새로운 폼팩터 디스플레이가 적용된 IT 기기에 높은 투자 매력을 느끼는 반도체 중심의 기술 투자자입니다.",
        "저궤도 위성 통신과 재사용 발사체 기술의 미래 가치를 높게 평가하며, 위성 데이터 활용 서비스 산업에서 사회·경제적 기회를 찾고, 실생활에서는 정밀 위치 기반 서비스의 투자 매력도를 긍정적으로 보는 우주 산업 개척자입니다.",
        "이산화탄소 포집 및 순환 소재 기술을 미래 유망 기술로 꼽고, ESG 경영 관련 산업에서 사회적 변화의 기회를 모색하며, 실생활에서는 대체 식품과 같은 푸드테크 분야의 투자 매력도를 높게 평가하는 지속가능성 중심의 투자자입니다.",
    ],
    "investment_emotions": [
        "유망한 투자처를 남들보다 먼저 발견하여 자산 성장을 추구하며, 보유 자산의 가치가 일시적으로 하락하더라도 장기적인 관점에서 크게 신경 쓰지 않고 새로운 성장 동력을 탐색하는 데 집중하는 투자자입니다.",
        "인플레이션이나 예상치 못한 위험으로부터 내 자산을 안전하게 지키는 것을 중요하게 생각하며, 투자 상품의 가치가 하락했을 때 '더 저렴할 때 살걸' 또는 '고점에 팔걸' 하는 아쉬움을 느끼는 신중한 투자자입니다.",
        "시장 붕괴나 금리 인상 같은 악재를 미리 파악하여 손실을 피하는 것을 최우선으로 생각하고, 자산 가치 하락 시에는 손실이 더 커질까 봐 불안해하며 계속해서 계좌를 확인하는 위험 회피형 투자자입니다.",
        "투자를 위해 최소한의 정보는 알아야 한다는 의무감으로 정보를 탐색하지만, 실제 가치 하락을 겪으면 '역시 투자는 위험해'라며 투자를 시작한 것을 후회하는 경향이 있는 투자자입니다.",
        "새로운 성장 동력이나 유망한 투자처를 남들보다 먼저 발견하여 자산 성장을 목표로 하지만, 가치 하락 시에는 '더 저렴할 때 살걸' 혹은 '고점에 팔걸' 하는 아쉬움을 느끼는 적극적인 기회 탐색형 투자자입니다.",
        "내 자산을 인플레이션이나 예상치 못한 위험으로부터 안전하게 지키는 것을 우선시하며, 일시적인 시장 변동에는 장기적인 관점에서 크게 신경 쓰지 않는 안정 추구형 투자자입니다.",
        "시장 붕괴 같은 악재를 미리 파악하여 손실을 피하는 것을 최우선으로 여기며, 실제 손실이 발생하면 '투자를 시작하지 말았어야 했나' 하고 크게 후회하는 극단적인 손실 회피형 투자자입니다.",
        "유망한 투자처를 발견하여 자산 성장을 이루고 싶어 하지만, 보유 자산의 가치가 하락하면 손실이 더 커질까 봐 불안해하며 계속 계좌를 확인하는 성장 추구형이면서도 불안감이 높은 투자자입니다.",
        "투자에 대한 지식을 의무감으로 찾아보면서도, 일시적인 가치 하락에는 크게 신경 쓰지 않고 인플레이션 등의 위험으로부터 자산을 안전하게 지키려는 안정성을 중시하는 투자자입니다.",
        "내 자산을 안전하게 지키는 것을 중요하게 생각하면서도, 가치 하락 시에는 손실이 더 커질까 봐 불안해하며 시장 악재를 미리 파악하여 손실을 피하는 것을 최우선으로 생각하는 불안정한 안정 추구형 투자자입니다.",
    ],
    "investment_goal": [
        "투자 경험이 전혀 없고 3년 이내의 단기 투자 기간 동안 원금 손실을 절대 용납할 수 없는 안정적인 원금 보존을 최우선 목표로 하는 투자자입니다.",
        "약간의 투자 지식과 경험을 바탕으로 3년에서 5년의 투자 기간 동안 약간의 원금 손실 위험을 감수하며 예금 금리 이상의 안정적인 이자 수익을 추구하는 투자자입니다.",
        "약간의 투자 경험을 가지고 있으며, 5년 이상의 장기적인 관점에서 원금의 최대 20% 손실을 감수하며 시장 평균 수준의 수익률로 자산을 꾸준히 증식시키고자 하는 투자자입니다.",
        "상당한 투자 경험을 바탕으로 10년 이상의 장기 투자를 통해 20% 이상의 단기적인 손실을 감수하더라도 시장 평균을 초과하는 높은 수익을 추구하는 공격적인 투자자입니다.",
        "투자 경험은 없지만 5년 이상의 장기적인 관점에서 최대 20%의 원금 손실을 감수하며 시장 평균 수준의 수익률로 자산 증식을 목표로 하는 투자자입니다.",
        "상당한 투자 경험을 보유하고 있으며, 3년에서 5년의 기간 동안 약간의 원금 손실 위험을 감수하고 예금 금리 이상의 안정적인 이자 수익을 목표로 하는 투자자입니다.",
        "전문 투자자로서 10년 이상의 장기 투자를 통해 20% 이상의 단기 손실과 높은 위험을 감수하며 시장 평균을 초과하는 높은 수익을 목표로 하는 투자자입니다.",
        "약간의 투자 지식과 경험이 있지만 3년 이내의 단기 투자 기간 동안 원금 손실을 절대 용납하지 않으며 원금을 안전하게 보존하는 것을 최우선으로 생각하는 투자자입니다.",
        "투자 경험이 없는 초보 투자자이지만, 5년 이상의 장기적인 관점에서 예금 금리 이상의 수익을 위해 약간의 원금 손실 위험을 감수하며 자산을 꾸준히 증식시키기를 원하는 투자자입니다.",
        "상당한 투자 경험을 바탕으로 5년 이상의 장기적인 관점에서 최대 20%의 원금 손실을 감수하며 시장 평균 수준의 수익률로 자산을 꾸준히 증식시키는 것을 목표로 하는 투자자입니다.",
    ],
    "investment_level": [
        "투자 경험이 없어 원금 손실을 우려하며, 유망 종목을 몰라 포트폴리오 구성에 어려움을 느끼는 투자자입니다.",
        "소액으로 투자를 시작했으며, 시장 하락 시 장기적 회복을 믿고 보유하며, 전문가 추천 종목에 집중 투자하는 경향이 있습니다.",
        "2년 이상 직접 종목을 분석하여 꾸준히 투자해왔고, 시장 하락을 추가 매수 기회로 삼으며, 분산 투자의 중요성을 인지하고 있습니다.",
        "해외주식, 파생상품 등 다양한 자산 배분 전략을 직접 실행하고, 시장 하락 시 적극적으로 포트폴리오 리밸런싱을 하며, 정기적인 자산 비중 조절을 필수적으로 생각합니다.",
        "소액으로 투자를 시작했지만 원금 손실에 대한 두려움이 크며, 그럼에도 불구하고 분산 투자가 중요하다고 생각하는 투자자입니다.",
        "2년 이상 직접 종목을 선택하며 꾸준히 투자해왔고, 시장 하락 시 장기적 회복을 믿고 보유하며, 정기적인 자산 비중 조절이 필수적이라고 생각합니다.",
        "해외주식 및 대체투자를 포함한 자산 배분 전략을 직접 실행하고, 시장 하락을 추가 매수 기회로 활용하며, 분산 투자가 중요하다고 생각합니다.",
        "소액으로 투자를 시작한 단계이며, 시장 하락을 추가 매수의 기회로 삼을 수 있지만, 유망 종목을 잘 몰라 포트폴리오 구성에 어려움을 겪고 있습니다.",
        "2년 이상 스스로 종목을 분석하며 투자해왔고, 시장 하락 시 적극적으로 포트폴리오 리밸런싱을 실행하지만, 전문가 추천 종목에 집중 투자하는 것을 선호합니다.",
        "주로 예·적금을 이용해 투자 경험은 없지만, 시장 하락 시 장기적인 회복을 믿고 보유할 것이며, 정기적인 자산 비중 조절이 필수적이라고 생각하는 신중한 투자자입니다.",
    ],
    "knowledge_level": [
        "장기적 관점의 자산배분과 손실 회피 편향을 이해하지만, 포트폴리오의 최대 낙폭(MDD)을 수익 잠재력으로 잘못 해석하고 레버리지를 위험 관리 수단으로 여기는 등 리스크 관리 지식에 심각한 허점을 보이는 투자자.",
        "포트폴리오의 최대 낙폭(MDD) 위험과 안전자산의 역할을 이해하고 있음에도 불구하고, 실제 포트폴리오 구성은 100% 기술주 집중이라는 공격적인 방식을 선호하며 투자 심리 용어에 대한 이해가 부족하여 이론과 실제가 괴리된 투자자.",
        "최대 낙폭(MDD)의 위험성과 손절매 원칙의 중요성은 알고 있으나, 장기 투자를 위한 자산 배분은 지나치게 안정성에만 치중하고 투자 심리 용어를 부정확하게 이해하고 있어 실제 투자 적용 능력이 부족한 보수적 투자자.",
        "포트폴리오의 최대 낙폭(MDD) 관리 방법으로 주기적인 리밸런싱을 이해하고 있음에도, 시장 예측이 불가능하다는 비관론에 근거하여 성장 자산을 포기하고 현금과 금에만 의존하며 투자 심리 용어에 대한 이해도가 낮은 극단적 안전 추구형 투자자.",
        "장기적 관점의 자산배분, 손실 회피와 같은 투자 심리, 그리고 최대 낙폭(MDD)의 개념과 관리 방안에 대해 전반적으로 정확하고 균형 잡힌 지식을 갖춘 투자자.",
        "자산 배분은 극도로 보수적인 성향을 보이면서도, 최대 낙폭(MDD)을 수익 잠재력으로 오해하고 투자 심리 용어를 부정확하게 이해하는 등 투자 지식의 깊이가 얕고 일관성이 결여된 투자자.",
        "포트폴리오의 변동성 위험과 손절매 원칙의 중요성은 이해하고 있으나, 자산 배분은 위험 분산 없이 100% 기술주에 집중하고 투자 심리 용어에 대한 이해가 부족한, 공격적 성향의 단기 대응 중심 투자자.",
        "손실 회피 심리와 최대 낙폭(MDD) 관리의 필요성을 잘 이해하고 있지만, 그로 인해 성장 기회를 포기하고 현금과 금이라는 극단적인 안전자산에만 의존하는 과도한 위험 회피 성향의 투자자.",
        "합리적인 분산 투자 포트폴리오를 선택했으나, 최대 낙폭(MDD)을 수익의 기회로 여기고 레버리지를 긍정하는 등 투자의 핵심 위험 요소를 제대로 이해하지 못하고 있어 기초 지식이 매우 취약한 투자자.",
        "최대 낙폭(MDD)의 위험성을 인지하고 안전자산의 필요성을 이해하는 이론적 지식은 갖추었지만, 실제 투자에서는 100% 기술주 집중을 택하고 투자 심리 용어를 잘못 적용하는 등 이론과 실전이 분리된 공격적 성향의 투자자.",
    ],
    "risk_tolerance": [
        "시장의 변동성을 장기적인 관점에서 이해하고 있으며, 위험과 수익의 관계에 대한 지식을 바탕으로 합리적인 투자 결정을 내릴 수 있는 수준의 투자자입니다.",
        "높은 수익률에 대한 기대는 있으나, 실제 시장 변동성과 손실에 대한 이해가 부족하여 감정적인 투자 결정을 내릴 가능성이 높은 초보 투자자 수준입니다.",
        "자신의 보수적인 투자 목표를 명확히 인지하고 있으며, 시장의 단기적인 하락에도 장기적인 계획을 유지할 수 있는 투자 원칙에 대한 깊은 이해를 갖추고 있습니다.",
        "장기 투자와 자본 수익 추구라는 기본 개념은 이해하고 있으나, 실제 손실 상황에서는 심리적으로 흔들려 계획을 수정할 수 있는 중급 수준의 투자 지식을 보유하고 있습니다.",
        "자신의 투자 성향을 명확히 파악하고 있으며, 시장 변동성을 감내하며 장기적인 투자 계획을 꾸준히 실행할 수 있는 충분한 지식과 원칙을 갖춘 투자자입니다.",
        "시장 하락을 추가 투자의 기회로 활용할 만큼 대담하며, 높은 위험과 그에 따른 변동성에 대한 깊은 이해를 바탕으로 초과 수익을 추구하는 전문가 수준의 투자 지식을 보유하고 있습니다.",
        "투자 원금 손실에 대한 두려움이 매우 커서 안정성을 최우선으로 고려하며, 시장 변동성에 대한 대처 능력이 부족하여 기본적인 금융 상품 외의 투자에는 지식이 제한적인 상태입니다.",
        "장기적인 관점에서 시장의 회복 가능성을 이해하고 있으며, 투자 과정에서 발생하는 심리적 불안감을 통제하고 계획을 유지할 수 있는 중급 이상의 투자 지식을 갖추고 있습니다.",
        "예금 이상의 수익을 추구하는 목표는 있으나, 이론적인 손실 감내 수준과 실제 하락장에서의 감정적 대응 사이에 괴리가 있어 투자 경험과 지식이 더 필요한 단계입니다.",
        "공격적인 투자로 높은 수익을 얻고 싶어 하지만, 작은 손실에도 크게 스트레스를 받는 성향으로 보아, 위험 자산의 실제 변동성에 대한 이해가 부족한 자기과신형 투자자일 가능성이 높습니다.",
    ],
}
# Out:
# /Users/yopchi/Firenodes/Projects/FIREgen

# %%
summary = summary_list["knowledge_level"][4:6]
print(summary)
# Out:
# ['장기적 관점의 자산배분, 손실 회피와 같은 투자 심리, 그리고 최대 낙폭(MDD)의 개념과 관리 방안에 대해 전반적으로 정확하고 균형 잡힌 지식을 갖춘 투자자.', '자산 배분은 극도로 보수적인 성향을 보이면서도, 최대 낙폭(MDD)을 수익 잠재력으로 오해하고 투자 심리 용어를 부정확하게 이해하는 등 투자 지식의 깊이가 얕고 일관성이 결여된 투자자.']

# %%
from pydantic import BaseModel, Field

from my_app.chatbot.chat_core.model_loader import get_llm_models
from my_app.chatbot.chat_core.prompt_loader import load_prompt_from_yaml


class AnalysisData(BaseModel):
    data: list[str] = Field(
        description="""A list of strings containing the analysis result. 
        """
    )


class AnalysisRiskTolerance(BaseModel):
    data: int = Field(
        description="""this MUST be a list with a single string representing an integer score from 0 to 100, for example: ['75'].
        For other categories, this MUST be a list of strings.
        """
    )


CATEGORY_KEYS: list[str] = [
    "risk_tolerance",
]

# prompt = """
# You are a highly sophisticated financial AI profiler, designed to perform a single, critical task: to prudently assess an investor's true risk tolerance.
# Your mission is to analyze a list of sentences: {compacted_user_answer} describing a single investor, synthesize these data points, and distill it into a single, prudently assessed "Risk Tolerance Score" on a scale of 0 to 100.

# **Core Directive: The Prudence Principle**

# Your primary directive is the **Prudence Principle**. If the information provided is contradictory or inconsistent, you must assume the investor's true risk tolerance is lower than they might state. Uncertainty equals risk. Therefore, internal conflict in the data must result in a more conservative (lower) final score.

# **Evaluation Process:**

# 1.  **Holistic Analysis & Conflict Identification:** Read all provided sentences to build a unified profile. Your first goal is to identify any conflicts between the investor's stated goals, their emotional responses to risk, and their likely actions under pressure.

# 2.  **Apply the Prudence Principle:**
#     - **If the profile is consistent:** Determine the score based on the clear evidence. (e.g., a consistently aggressive investor gets a high score).
#     - **If the profile is inconsistent:** Your final score must be **heavily biased towards the most risk-averse piece of evidence**. Do not simply average the conflicting traits. The presence of fear, anxiety, or panicked selling is a powerful signal that overrides stated aggressive goals. The internal conflict itself demonstrates a lower capacity for risk.

# 3.  **Map to Scale & Assign Final Score:** Based on your analysis, map the investor's prudently assessed character to the scale below and determine the final integer score.

# **Risk Tolerance Score Scale:**

# - **0 (Extremely Risk-Averse):** Primary goal is 100% capital preservation. Experiences extreme stress from minor potential losses.
# - **25 (Conservative):** Seeks returns slightly above inflation. Uncomfortable with losses exceeding 5-10%.
# - **50 (Moderate / Balanced):** Understands the risk/reward trade-off. Can tolerate short-term drawdowns of 15-20%.
# - **75 (Growth-Oriented / Aggressive):** Aims for above-market returns. Comfortable with significant volatility and views downturns as opportunities.
# - **100 (Highly Aggressive / Speculative):** Unfazed by large drawdowns. Actively seeks out high-risk assets to maximize returns.

# **Output Rules:**

# - The final output must be a single integer ONLY.
# - Do not output any text, explanations, labels, JSON, or any characters other than the number itself.
# """


# prompt_template = PromptTemplate(
#     template=prompt, input_variables=["compacted_user_answer"]
# )

prompt_template = load_prompt_from_yaml("analysis_knowledge_level")

llm = get_llm_models("gpt-5-mini")

chain = prompt_template | llm.with_structured_output(AnalysisData)

result = chain.invoke(
    {
        "compacted_user_answer": summary,
    }
)

print(result)
# Out:
# Creating new LLM client for gpt-5-mini
# data=['Beginner']
